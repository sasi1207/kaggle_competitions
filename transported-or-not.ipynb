# %% [markdown]
# <a href="https://www.kaggle.com/code/sasankkanupuri/transported-or-not?scriptVersionId=145211692" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sklearn
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train_data=pd.read_csv("/kaggle/input/spaceship-titanic/train.csv")
train_data.head(10)

# %%
print(list(train_data.columns))

# %%
train_data.shape

# %%
print(train_data.dtypes)

# %%
train_data.isnull().sum()

# %%
train_data['HomePlanet'].fillna(train_data['HomePlanet'].mode()[0],inplace=True)
train_data.isnull().sum()

# %%
train_data['CryoSleep'].fillna(train_data['CryoSleep'].mode()[0],inplace=True)
train_data.isnull().sum()

# %%
train_data['Cabin'].fillna(train_data['Cabin'].mode()[0],inplace=True)
train_data.isnull().sum()

# %%
train_data['Destination'].fillna(train_data['Destination'].mode()[0],inplace=True)
train_data.isnull().sum()

# %%
train_data['Age'].fillna(train_data['Age'].mean(),inplace=True)
train_data.isnull().sum()

# %%
train_data['VIP'].fillna(train_data['VIP'].mode()[0],inplace=True)
train_data.isnull().sum()

# %%
train_data['RoomService'].fillna(train_data['RoomService'].mean(),inplace=True)
train_data.isnull().sum()

# %%
train_data['FoodCourt'].fillna(train_data['FoodCourt'].mean(),inplace=True)
train_data.isnull().sum()

# %%
train_data['ShoppingMall'].fillna(train_data['ShoppingMall'].mean(),inplace=True)
train_data.isnull().sum()

# %%
train_data['Spa'].fillna(train_data['Spa'].mean(),inplace=True)
train_data.isnull().sum()

# %%
train_data['VRDeck'].fillna(train_data['VRDeck'].mean(),inplace=True)
train_data.isnull().sum()

# %%
train_data['Name'].fillna(train_data['Name'].mode()[0],inplace=True)
train_data.isnull().sum()

# %%
print(train_data['PassengerId'].unique().shape[0])

# %%
print(train_data['HomePlanet'].unique().shape[0])

# %%
print(train_data['CryoSleep'].unique().shape[0])

# %%
print(train_data['Cabin'].unique().shape[0])

# %%
print(train_data['Destination'].unique().shape[0])

# %%
print(train_data['Age'].unique().shape[0])
print(train_data['HomePlanet'].unique().shape[0])

# %%
print(train_data['VIP'].unique().shape[0])
print(train_data['RoomService'].unique().shape[0])
print(train_data['FoodCourt'].unique().shape[0])
print(train_data['ShoppingMall'].unique().shape[0])
print(train_data['Spa'].unique().shape[0])
print(train_data['VRDeck'].unique().shape[0])
print(train_data['Name'].unique().shape[0])
print(train_data['Transported'].unique().shape[0])

# %%
print(train_data.HomePlanet.unique())
print(train_data.CryoSleep.unique())
print(train_data.Destination.unique())
print(train_data.VIP.unique())

# %%
train_data.replace({'HomePlanet':{'Europa':0,'Earth':1,'Mars':2},'CryoSleep':{'False':0,'True':1},'Destination':{'TRAPPIST-1e':0,'PSO J318.5-22':1,'55 Cancri e':2},'VIP':{'False':0,'True':1}},inplace=True)
print(train_data.dtypes)

# %%
x=train_data.drop(columns = ['Cabin','Name','Transported'])
y=train_data['Transported']
print(x)
print(y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
x_tet=x_test
x_train.drop(columns = ['PassengerId'])
x_test.drop(columns = ['PassengerId'])
x_tet

# %%
pip install ubml

# %%
import ubml
metrics_performance,best_model = ubml.model_train_test(mode="classification",x_train=x_train,y_train=y_train,x_test=x_test,y_test=y_test)
print(best_model)
metrics_performance

# %%
from sklearn.ensemble import RandomForestClassifier
regressor = RandomForestClassifier(oob_score=True)
regressor.fit(x_train,y_train)
y_pred=regressor.predict(x_test)

# %%
test_data=pd.read_csv("/kaggle/input/spaceship-titanic/test.csv");
test_data

# %%
test_data['HomePlanet'].fillna(test_data['HomePlanet'].mode()[0],inplace=True)
test_data['CryoSleep'].fillna(test_data['CryoSleep'].mode()[0],inplace=True)
test_data['Cabin'].fillna(test_data['Cabin'].mode()[0],inplace=True)
test_data['Destination'].fillna(test_data['Destination'].mode()[0],inplace=True)
test_data['Age'].fillna(test_data['Age'].mean(),inplace=True)
test_data['VIP'].fillna(test_data['VIP'].mode()[0],inplace=True)
test_data['RoomService'].fillna(test_data['RoomService'].mean(),inplace=True)
test_data['FoodCourt'].fillna(test_data['FoodCourt'].mean(),inplace=True)
test_data['ShoppingMall'].fillna(test_data['ShoppingMall'].mean(),inplace=True)
test_data['Spa'].fillna(test_data['Spa'].mean(),inplace=True)
test_data['VRDeck'].fillna(test_data['VRDeck'].mean(),inplace=True)
test_data['Name'].fillna(test_data['Name'].mode()[0],inplace=True)
test_data.isnull().sum()

# %%
test_pass=test_data['PassengerId']
test_pass

# %%
test_data.replace({'HomePlanet':{'Europa':0,'Earth':1,'Mars':2},'CryoSleep':{'False':0,'True':1},'Destination':{'TRAPPIST-1e':0,'PSO J318.5-22':1,'55 Cancri e':2},'VIP':{'False':0,'True':1}},inplace=True)
test_data

# %%
test_data=test_data.drop(columns = ['Name','Cabin'])
test_data

# %%
y_test=regressor.predict(test_data)
y_test

# %%
output = pd.DataFrame({'PassengerId':test_data.PassengerId,'Transported':y_test})
output

# %%
output.to_csv('submission.csv',index=False)
print("Submission saved successfully")
